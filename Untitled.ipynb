# %%
import pandas as pd
import numpy as np

size, scale = 1000, 10
commutes = pd.Series(np.random.gamma(scale, size=size) ** 1.5)

commutes.plot.hist(grid=True, bins=20, rwidth=0.9,
                   color='#607c8e')
plt.title('Commute Times for 1,000 Commuters')
plt.xlabel('Counts')
plt.ylabel('Commute Time')
plt.grid(axis='y', alpha=0.75)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-45db34eb43ff> in <module>
#       7 commutes.plot.hist(grid=True, bins=20, rwidth=0.9,
#       8                    color='#607c8e')
# ----> 9 plt.title('Commute Times for 1,000 Commuters')
#      10 plt.xlabel('Counts')
#      11 plt.ylabel('Commute Time')
#
# NameError: name 'plt' is not defined

# %%
df = pd.DataFrame({'length': [1.5, 0.5, 1.2, 0.9, 3],'width': [0.7, 0.2, 0.15, 0.2, 1.1]}, index= ['pig', 'rabbit', 'duck', 'chicken', 'horse'])
hist = df.hist(bins=3)
